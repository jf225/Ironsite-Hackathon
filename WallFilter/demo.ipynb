# %%
import torch
from transformers import CLIPProcessor, CLIPModel
import cv2
import os
from PIL import Image

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
video_path = "actual_site_footage.mp4"
output_folder = "clip_wall_frames"
output_folder_2 = "clip_wall_fails"
os.makedirs(output_folder, exist_ok=True)
os.makedirs(output_folder_2, exist_ok=True)

fps_target = 5          # downsample video
batch_size = 16         # frames per batch
threshold = 0.04          # similarity threshold for relevance
device = "cuda" if torch.cuda.is_available() else "cpu"

# Positive and negative prompts
positive_prompts = [
    "wall under construction",
    "construction site wall",
    "concrete blocks",
    "concrete bricks",
    "wall being built"
]

negative_prompts = [
    "closeby worker",
    "distant parking lot",
    "wheelbarrow",
    "wet concrete",
    "lots of orange fencing close by",
    "looking down over ledge"
]

# %%
model_name = "openai/clip-vit-base-patch32"
clip_model = CLIPModel.from_pretrained(model_name).to(device)
clip_processor = CLIPProcessor.from_pretrained(model_name)
# Out:
# Loading weights: 100%|██████████| 398/398 [00:00<00:00, 1530.00it/s, Materializing param=visual_projection.weight]
# Loading weights: 100%|██████████| 398/398 [00:00<00:00, 1530.00it/s, Materializing param=visual_projection.weight]
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# text_model.embeddings.position_ids   | UNEXPECTED |  |
# vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# text_model.embeddings.position_ids   | UNEXPECTED |  |
# vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
def encode_prompts(prompts):
    inputs = clip_processor(text=prompts, return_tensors="pt", padding=True).to(device)
    with torch.no_grad():
        outputs = clip_model.get_text_features(**inputs)
        if hasattr(outputs, "text_embeds"):
            features = outputs.text_embeds
        elif hasattr(outputs, "pooler_output"):
            features = outputs.pooler_output
        elif hasattr(outputs, "last_hidden_state"):
            features = outputs.last_hidden_state.mean(dim=1)
        else:
            raise ValueError("Cannot extract tensor from CLIP text output")
        features = features / features.norm(dim=-1, keepdim=True)
    return features

text_features_pos = encode_prompts(positive_prompts)
text_features_neg = encode_prompts(negative_prompts)

# %%
def compute_image_features(frames):
    pil_imgs = [Image.fromarray(cv2.cvtColor(f, cv2.COLOR_BGR2RGB)) for f in frames]
    inputs = clip_processor(images=pil_imgs, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = clip_model.get_image_features(**inputs)
        if hasattr(outputs, "image_embeds"):
            img_features = outputs.image_embeds
        elif hasattr(outputs, "pooler_output"):
            img_features = outputs.pooler_output
        elif hasattr(outputs, "last_hidden_state"):
            img_features = outputs.last_hidden_state.mean(dim=1)
        else:
            raise ValueError("Cannot extract tensor from CLIP image output")
        img_features = img_features / img_features.norm(dim=-1, keepdim=True)
    return img_features

# %%
def center_crop(frame, crop_frac=0.8):
    h, w, _ = frame.shape
    x1 = int(w*(1-crop_frac)/2)
    x2 = int(w*(1+crop_frac)/2)
    y1 = int(h*(1-crop_frac)/2)
    y2 = int(h*(1+crop_frac)/2)
    return frame[y1:y2, x1:x2]

# %%
cap = cv2.VideoCapture(video_path)
orig_fps = cap.get(cv2.CAP_PROP_FPS)
skip = 10

frame_count = 0
selected_count = 0
batch_frames = []
batch_frames_full = []
batch_indices = []
last_check = 1
thres = threshold

while True:
    ret, frame = cap.read()
    if not ret:
        break

    if frame_count % skip == 0:
        cropped = center_crop(frame)
        batch_frames.append(cropped)
        batch_frames_full.append(frame)
        batch_indices.append(frame_count)

    if len(batch_frames) == batch_size:
        img_features = compute_image_features(batch_frames)
        # Positive and negative similarity
        sims_pos = img_features @ text_features_pos.T  # (batch_size, #pos_prompts)
        sims_neg = img_features @ text_features_neg.T  # (batch_size, #neg_prompts)
        relevance_scores = sims_pos.max(dim=1).values - sims_neg.max(dim=1).values
        relevance_scores = relevance_scores.cpu().numpy()

        for i, score in enumerate(relevance_scores):
            #print(f"{sims_pos.max(dim=1).values} vs {sims_neg.max(dim=1).values} for {frame_count}")
            if last_check == 0:
                thres = threshold * 1.7
            else:
                thres = threshold
            if score >= threshold:
                out_path = os.path.join(output_folder, f"frame_{batch_indices[i]:06d}.png")
                cv2.imwrite(out_path, batch_frames_full[i])
                last_check = 1
                selected_count += 1
            else:
                last_check = 0
                out_path = os.path.join(output_folder_2, f"frame_{batch_indices[i]:06d}.png")
                cv2.imwrite(out_path, batch_frames_full[i])

        batch_frames, batch_frames_full, batch_indices = [], [], []

    frame_count += 1
    print(f"{selected_count} out of {frame_count//skip} frames added")

# Process remaining frames
if batch_frames:
    img_features = compute_image_features(batch_frames)
    sims_pos = img_features @ text_features_pos.T
    sims_neg = img_features @ text_features_neg.T
    relevance_scores = sims_pos.max(dim=1).values - sims_neg.max(dim=1).values
    relevance_scores = relevance_scores.cpu().numpy()

    for i, score in enumerate(relevance_scores):
        if score >= threshold:
            out_path = os.path.join(output_folder, f"frame_{batch_indices[i]:06d}.png")
            cv2.imwrite(out_path, batch_frames[i])
            selected_count += 1

cap.release()
print(f"Saved {selected_count} frames to '{output_folder}'")
# Out:
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 0 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 1 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 2 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 3 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 4 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 5 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 6 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 7 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 8 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 9 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 10 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 11 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 12 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 13 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 14 frames added
# 0 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 31 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 15 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 16 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 17 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 18 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 19 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 20 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 21 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 22 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 23 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 24 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 25 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 26 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 27 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 28 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 29 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 30 frames added
# 15 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 47 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 31 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 32 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 33 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 34 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 35 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 36 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 37 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 38 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 39 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 40 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 41 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 42 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 43 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 44 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 45 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 46 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 63 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 47 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 48 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 49 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 50 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 51 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 52 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 53 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 54 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 55 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 56 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 57 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 58 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 59 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 60 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 61 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 62 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 79 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 63 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 64 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 65 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 66 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 67 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 68 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 69 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 70 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 71 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 72 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 73 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 74 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 75 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 76 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 77 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 78 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 95 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 79 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 80 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 81 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 82 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 83 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 84 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 85 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 86 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 87 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 88 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 89 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 90 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 91 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 92 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 93 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 94 frames added
# 27 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 95 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 96 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 97 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 98 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 99 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 100 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 101 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 102 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 103 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 104 frames added
# 28 out of 105 frames added
# 28 out of 105 frames added
# 28 out of 105 frames added
# 28 out of 105 frames added
# ...
# 285 out of 1886 frames added
# 285 out of 1886 frames added
# 285 out of 1886 frames added
# 285 out of 1886 frames added
# 285 out of 1886 frames added
# 285 out of 1886 frames added
# 285 out of 1886 frames added
# 285 out of 1886 frames added
# 285 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1903 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1887 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1888 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1889 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1890 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1891 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1892 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1893 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1894 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1895 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1896 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1897 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1898 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1899 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1900 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1901 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1902 frames added
# 286 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1914 frames added
# Saved 288 frames to 'clip_wall_frames'
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1903 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1904 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1905 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1906 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1907 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1908 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1909 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1910 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1911 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1912 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1913 frames added
# 287 out of 1914 frames added
# Saved 288 frames to 'clip_wall_frames'
